# %% [markdown]
# # Population
# ## 인구

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns   
import pdtypes

# %%
pop = pd.read_csv('data/pop.csv')
pop
# Out:
#                   country     1800     1801     1802     1803     1804  \
#                  <object> <object> <object> <object> <object> <object>
# 0             Afghanistan    3.28M    3.28M    3.28M    3.28M    3.28M
# 1                  Angola    1.57M    1.57M    1.57M    1.57M    1.57M
# 2                 Albania     400k     402k     404k     405k     407k
# 3                 Andorra     2650     2650     2650     2650     2650
# ..                    ...      ...      ...      ...      ...      ...
# 4    United Arab Emirates    40.2k    40.2k    40.2k    40.2k    40.2k
# 192                 Samoa    47.3k    47.3k    47.3k    47.3k    47.3k
# 193                 Yemen    2.59M    2.59M    2.59M    2.59M    2.59M
# 194          South Africa    1.45M    1.45M    1.46M    1.46M    1.47M
# 195                Zambia     747k     758k     770k     782k     794k
# 196              Zimbabwe    1.09M    1.09M    1.09M    1.09M    1.09M
#
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Columns: 302 entries, country to 2100
# dtypes: object(302)
# memory usage: 464.9+ KB

# %%
pop.shape
# Out:
# (197, 302)

# %%
kor = pop.loc[pop['country']=='South Korea',]
kor.columns
# Out:
# Index(['country', '1800', '1801', '1802', '1803', '1804', '1805', '1806',
#        '1807', '1808',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=302)

# %%
sns.lineplot(data=kor.T, x=columns, y='South Korea')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18652\3397007371.py in <cell line: 1>()
# ----> 1 sns.lineplot(data=kor.T, x=columns, y='South Korea')
#
# NameError: name 'columns' is not defined

# %%
kor
# Out:
#         country     1800     1801     1802     1803     1804     1805  \
#        <object> <object> <object> <object> <object> <object> <object>
# 95  South Korea    9.39M    9.39M    9.39M    9.39M    9.39M    9.39M
#
#        1806     1807     1808  ...     2091     2092     2093     2094  \
#    <object> <object> <object>  ... <object> <object> <object> <object>
# 95    9.39M    9.39M    9.39M           27M    26.7M    26.3M      26M
#
#        2095     2096     2097     2098     2099     2100
#    <object> <object> <object> <object> <object> <object>
# 95    25.6M    25.3M      25M    24.7M    24.4M    24.1M
#
# [1 rows x 302 columns]
