# %% [markdown]
# # GapMinder's Data
# ## world development indecators/contry

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns   
import pdtypes

# %%
country = pd.read_csv('data/ddf--entities--geo--country.csv')
country
# Out:
#        country g77_and_oecd_countries income_3groups        income_groups  \
#       <object>               <object>       <object>             <object>
# 0         abkh                 others            NaN                  NaN
# 1          abw                 others    high_income          high_income
# 2          afg                    g77     low_income           low_income
# 3          ago                    g77  middle_income  lower_middle_income
# ..         ...                    ...            ...                  ...
# 4          aia                 others            NaN                  NaN
# 268  yem_south                 others            NaN                  NaN
# 269        yug                 others            NaN                  NaN
# 270        zaf                    g77  middle_income  upper_middle_income
# 271        zmb                    g77  middle_income  lower_middle_income
# 272        zwe                    g77  middle_income  lower_middle_income
#
# ...

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 273 non-null    object
#  1   g77_and_oecd_countries  259 non-null    object
#  2   income_3groups          218 non-null    object
#  3   income_groups           218 non-null    object
#  4   is--country             273 non-null    bool
#  5   iso3166_1_alpha2        248 non-null    object
#  6   iso3166_1_alpha3        247 non-null    object
#  7   iso3166_1_numeric       247 non-null    float64
#  8   iso3166_2               1 non-null      object
#  9   landlocked              255 non-null    object
#  10  latitude                241 non-null    float64
#  11  longitude               241 non-null    float64
#  12  main_religion_2008      216 non-null    object
#  13  name                    273 non-null    object
# ...

# %%
w4r = country.value_counts('world_4region', ascending=False, dropna=True)
#w4r.index
display(w4r)
# Out:
# world_4region
# asia        80
# europe      73
# africa      61
# americas    57
# dtype: int64

# %%
plt.rc('font',family='Malgun Gothic')

# %%
w4rindex = ['아시아','유럽','아프리카','아메리카']

plt.figure(figsize=(4, 4))
plt.pie(w4r, labels = w4rindex, autopct='%.1f%%')
plt.show()

# %%
country
# Out:
#        country g77_and_oecd_countries income_3groups        income_groups  \
#       <object>               <object>       <object>             <object>
# 0         abkh                 others            NaN                  NaN
# 1          abw                 others    high_income          high_income
# 2          afg                    g77     low_income           low_income
# 3          ago                    g77  middle_income  lower_middle_income
# ..         ...                    ...            ...                  ...
# 4          aia                 others            NaN                  NaN
# 268  yem_south                 others            NaN                  NaN
# 269        yug                 others            NaN                  NaN
# 270        zaf                    g77  middle_income  upper_middle_income
# 271        zmb                    g77  middle_income  lower_middle_income
# 272        zwe                    g77  middle_income  lower_middle_income
#
# ...

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 273 non-null    object
#  1   g77_and_oecd_countries  259 non-null    object
#  2   income_3groups          218 non-null    object
#  3   income_groups           218 non-null    object
#  4   is--country             273 non-null    bool
#  5   iso3166_1_alpha2        248 non-null    object
#  6   iso3166_1_alpha3        247 non-null    object
#  7   iso3166_1_numeric       247 non-null    float64
#  8   iso3166_2               1 non-null      object
#  9   landlocked              255 non-null    object
#  10  latitude                241 non-null    float64
#  11  longitude               241 non-null    float64
#  12  main_religion_2008      216 non-null    object
#  13  name                    273 non-null    object
# ...

# %%
religion = country.value_counts('main_religion_2008', ascending=False)
religion
# Out:
# main_religion_2008
# christian            153
# muslim                48
# eastern_religions     15
# dtype: int64

# %%
rel_country = country['main_religion_2008'].fillna('no data')
rel_country
# Out:
# 0        no data
# 1      christian
# 2         muslim
# 3      christian
# 4      christian
#          ...
# 268      no data
# 269      no data
# 270    christian
# 271    christian
# 272    christian
# Name: main_religion_2008, Length: 273, dtype: object

# %%
religion = rel_country.value_counts('main_religion_2008', ascending=False)
religion
# Out:
# christian            0.560440
# no data              0.208791
# muslim               0.175824
# eastern_religions    0.054945
# Name: main_religion_2008, dtype: float64

# %%
labels = ['크리스챤','데이터없음', '무슬림','불교외동양종교']

plt.figure(figsize=(4,4))    
plt.pie(religion, labels = labels, autopct='%.1f%%') 
plt.show()

# %%
country
# Out:
#        country g77_and_oecd_countries income_3groups        income_groups  \
#       <object>               <object>       <object>             <object>
# 0         abkh                 others            NaN                  NaN
# 1          abw                 others    high_income          high_income
# 2          afg                    g77     low_income           low_income
# 3          ago                    g77  middle_income  lower_middle_income
# ..         ...                    ...            ...                  ...
# 4          aia                 others            NaN                  NaN
# 268  yem_south                 others            NaN                  NaN
# 269        yug                 others            NaN                  NaN
# 270        zaf                    g77  middle_income  upper_middle_income
# 271        zmb                    g77  middle_income  lower_middle_income
# 272        zwe                    g77  middle_income  lower_middle_income
#
# ...

# %%
country.columns
# Out:
# Index(['country', 'g77_and_oecd_countries', 'income_3groups', 'income_groups',
#        'is--country', 'iso3166_1_alpha2', 'iso3166_1_alpha3',
#        'iso3166_1_numeric', 'iso3166_2', 'landlocked', 'latitude', 'longitude',
#        'main_religion_2008', 'name', 'un_sdg_ldc', 'un_sdg_region', 'un_state',
#        'unhcr_region', 'unicef_region', 'unicode_region_subtag',
#        'west_and_rest', 'world_4region', 'world_6region'],
#       dtype='object')

# %%
country.value_counts('income_groups')
# Out:
# income_groups
# high_income            80
# upper_middle_income    60
# lower_middle_income    47
# low_income             31
# dtype: int64

# %%
country1 = country.copy()
country1['income_groups'] = country1['income_groups'].fillna('no datas')
country1
# Out:
#        country g77_and_oecd_countries income_3groups        income_groups  \
#       <object>               <object>       <object>             <object>
# 0         abkh                 others            NaN             no datas
# 1          abw                 others    high_income          high_income
# 2          afg                    g77     low_income           low_income
# 3          ago                    g77  middle_income  lower_middle_income
# ..         ...                    ...            ...                  ...
# 4          aia                 others            NaN             no datas
# 268  yem_south                 others            NaN             no datas
# 269        yug                 others            NaN             no datas
# 270        zaf                    g77  middle_income  upper_middle_income
# 271        zmb                    g77  middle_income  lower_middle_income
# 272        zwe                    g77  middle_income  lower_middle_income
#
# ...

# %%
income = country1.value_counts('income_groups')
income.index
# Out:
# Index(['high_income', 'upper_middle_income', 'no datas', 'lower_middle_income',
#        'low_income'],
#       dtype='object', name='income_groups')

# %%
lable1 = ['4단계(상위)','3단계(중상위)','데이터없음','2단계(중하위)','1단계(하위)']

plt.figure(figsize=(4,4))
plt.pie(income, labels = lable1, autopct="%.1f%%")
plt.show()

# %%
country
# Out:
#        country g77_and_oecd_countries income_3groups        income_groups  \
#       <object>               <object>       <object>             <object>
# 0         abkh                 others            NaN                  NaN
# 1          abw                 others    high_income          high_income
# 2          afg                    g77     low_income           low_income
# 3          ago                    g77  middle_income  lower_middle_income
# ..         ...                    ...            ...                  ...
# 4          aia                 others            NaN                  NaN
# 268  yem_south                 others            NaN                  NaN
# 269        yug                 others            NaN                  NaN
# 270        zaf                    g77  middle_income  upper_middle_income
# 271        zmb                    g77  middle_income  lower_middle_income
# 272        zwe                    g77  middle_income  lower_middle_income
#
# ...

# %%
country = country.rename({'is--country':'iscountry'}, axis=1)

# %%
country
# Out:
#        country g77_and_oecd_countries income_3groups        income_groups  \
#       <object>               <object>       <object>             <object>
# 0         abkh                 others            NaN                  NaN
# 1          abw                 others    high_income          high_income
# 2          afg                    g77     low_income           low_income
# 3          ago                    g77  middle_income  lower_middle_income
# ..         ...                    ...            ...                  ...
# 4          aia                 others            NaN                  NaN
# 268  yem_south                 others            NaN                  NaN
# 269        yug                 others            NaN                  NaN
# 270        zaf                    g77  middle_income  upper_middle_income
# 271        zmb                    g77  middle_income  lower_middle_income
# 272        zwe                    g77  middle_income  lower_middle_income
#
# ...

# %%
(country
 .query(" g77_and_oecd_countries == 'oecd' ")
 #.query(" iscountry==True")
 .loc[:,['country']]
 .size
)
# Out:
# 31

# %%
country.value_counts('g77_and_oecd_countries')
# Out:
# g77_and_oecd_countries
# g77       130
# others     98
# oecd       31
# dtype: int64

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 273 non-null    object
#  1   g77_and_oecd_countries  259 non-null    object
#  2   income_3groups          218 non-null    object
#  3   income_groups           218 non-null    object
#  4   iscountry               273 non-null    bool
#  5   iso3166_1_alpha2        248 non-null    object
#  6   iso3166_1_alpha3        247 non-null    object
#  7   iso3166_1_numeric       247 non-null    float64
#  8   iso3166_2               1 non-null      object
#  9   landlocked              255 non-null    object
#  10  latitude                241 non-null    float64
#  11  longitude               241 non-null    float64
#  12  main_religion_2008      216 non-null    object
#  13  name                    273 non-null    object
# ...

# %%
country.loc[country['g77_and_oecd_countries'].isnull() == True,['country']].size
# Out:
# 14

# %%
country.loc[country['g77_and_oecd_countries'].isnull() == False,['country']].size
# Out:
# 259

# %%
country2 = country.copy()
country2['g77_and_oecd_countries'] = country['g77_and_oecd_countries'].fillna('no data')

# %%
oecd = country2.value_counts('g77_and_oecd_countries')

# %%
labels3 = ['G-77', '가입안함','OECD','데이터없음']

plt.figure(figsize=(4,4))
plt.pie(oecd, labels=labels3, autopct='%.lf%%')
plt.show()
